# %%
#Code task 1#
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# the supplied CSV data file is the raw_data directory
Airbnb_data = pd.read_csv('C:/Users/Mohammad/Documents/listings.csv')

# %%
#Code task 2#
#Call the info method on ski_data to see a summary of the data
Airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258 entries, 0 to 2257
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2258 non-null   int64
#  1   name                            2258 non-null   object
#  2   host_id                         2258 non-null   int64
#  3   host_name                       2257 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   2258 non-null   int64
#  6   latitude                        2258 non-null   float64
#  7   longitude                       2258 non-null   float64
#  8   room_type                       2258 non-null   object
#  9   price                           2258 non-null   int64
#  10  minimum_nights                  2258 non-null   int64
#  11  number_of_reviews               2258 non-null   int64
# ...

# %%
#Code task 3#
#Call the head method on ski_data to print the first several rows of the data
Airbnb_data.head()
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 2  156926             Mixed Dorm "Top Bunk #1" at BPS Hostel   746673
# 3  160594                                Historic Grove Park   769252
# 4  209068                                    Terrace Cottage  1029919
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0       Lisa                  NaN          28801  35.60670  -82.55563
# 1    BonPaul                  NaN          28806  35.57864  -82.59578
# 2    BonPaul                  NaN          28806  35.57864  -82.59578
# 3  Elizabeth                  NaN          28801  35.61442  -82.54127
# 4      Kevin                  NaN          28804  35.61856  -82.55276
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Code task 5#
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#ski_data as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([Airbnb_data.isnull().sum(), 100 * Airbnb_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'])
# Out:
#                                 count           %
# id                                  0    0.000000
# name                                0    0.000000
# host_id                             0    0.000000
# neighbourhood                       0    0.000000
# latitude                            0    0.000000
# longitude                           0    0.000000
# room_type                           0    0.000000
# price                               0    0.000000
# minimum_nights                      0    0.000000
# number_of_reviews                   0    0.000000
# calculated_host_listings_count      0    0.000000
# availability_365                    0    0.000000
# host_name                           1    0.044287
# last_review                       175    7.750221
# reviews_per_month                 175    7.750221
# neighbourhood_group              2258  100.000000

# %%
#Code task 6#
#Use ski_data's `select_dtypes` method to select columns of dtype 'object'
Airbnb_data.select_dtypes(include=['object'])
# Out:
#                                                    name      host_name  \
# 0     Walk to stores/parks/downtown. Fenced yard/Pet...           Lisa
# 1                    Cottage! BonPaul + Sharky's Hostel        BonPaul
# 2                Mixed Dorm "Top Bunk #1" at BPS Hostel        BonPaul
# 3                                   Historic Grove Park      Elizabeth
# 4                                       Terrace Cottage          Kevin
# ...                                                 ...            ...
# 2253  Delightful Double Two Double Beds Non Smoking ...  Team Gospodin
# 2254                  Luxurious Double Bed At Asheville  Team Gospodin
# 2255                   En-Suite Double Bed At Asheville  Team Gospodin
# 2256                                            Big Red          Steve
# 2257  Lofts at Woolworth in downtown Asheville NC! #203          Scott
#
#             room_type last_review
# 0     Entire home/apt  2019-11-30
# 1     Entire home/apt  2020-12-06
# ...

# %%
#Code task 7#
#Use pandas' Series method `value_counts` to find any duplicated house names
Airbnb_data['name'].value_counts().head()
# Out:
# Luxury Condominium in the Center of Downtown Asheville                      4
# Downtown Gorgeous Garden Homestay: Private Room                             3
# Appealing Double Bed Non Smoking At Asheville                               2
# West Asheville Dream Location!                                              2
# New luxury 2 bdr/2 bath condo located in the heart of downtown Asheville    2
# Name: name, dtype: int64

# %%
#Code task 8#
#Concatenate the string columns 'Name' and 'Region' and count the values again (as above)
(Airbnb_data['name'] + ', ' + Airbnb_data['host_name']+','+Airbnb_data['room_type']).value_counts().head()
# Out:
# Luxury Condominium in the Center of Downtown Asheville, Towns,Entire home/apt                      4
# Downtown Gorgeous Garden Homestay: Private Room, Joanie,Private room                               3
# West Asheville Dream Location!, Caroline,Entire home/apt                                           2
# Appealing Double Bed Non Smoking At Asheville, Team Gospodin,Private room                          2
# New luxury 2 bdr/2 bath condo located in the heart of downtown Asheville, Towns,Entire home/apt    2
# dtype: int64

# %%
#Code task 9#
#Concatenate 'Name' and 'state' and count the values again (as above)
(Airbnb_data['name'] + ', ' + Airbnb_data['room_type']).value_counts().head()
# Out:
# Luxury Condominium in the Center of Downtown Asheville, Entire home/apt                      4
# Downtown Gorgeous Garden Homestay: Private Room, Private room                                3
# New luxury 2 bdr/2 bath condo located in the heart of downtown Asheville, Entire home/apt    2
# Appealing Double Bed Non Smoking At Asheville, Private room                                  2
# West Asheville Dream Location!, Entire home/apt                                              2
# dtype: int64

# %%
Airbnb_data.drop_duplicates()
# Out:
#             id                                               name    host_id  \
# 0       108061  Walk to stores/parks/downtown. Fenced yard/Pet...     320564
# 1       155305                 Cottage! BonPaul + Sharky's Hostel     746673
# 2       156926             Mixed Dorm "Top Bunk #1" at BPS Hostel     746673
# 3       160594                                Historic Grove Park     769252
# 4       209068                                    Terrace Cottage    1029919
# ...        ...                                                ...        ...
# 2253  47087442  Delightful Double Two Double Beds Non Smoking ...  175128252
# 2254  47088621                  Luxurious Double Bed At Asheville  175128252
# 2255  47088631                   En-Suite Double Bed At Asheville  175128252
# 2256  47091897                                            Big Red  231291927
# 2257  47096192  Lofts at Woolworth in downtown Asheville NC! #203  367363875
#
# ...

# %%
(Airbnb_data['name'] + ', ' + Airbnb_data['room_type']).value_counts().head()
# Out:
# Luxury Condominium in the Center of Downtown Asheville, Entire home/apt                      4
# Downtown Gorgeous Garden Homestay: Private Room, Private room                                3
# New luxury 2 bdr/2 bath condo located in the heart of downtown Asheville, Entire home/apt    2
# Appealing Double Bed Non Smoking At Asheville, Private room                                  2
# West Asheville Dream Location!, Entire home/apt                                              2
# dtype: int64

# %%
Airbnb_data[Airbnb_data.name=='Luxury Condominium in the Center of Downtown Asheville']
# Out:
#             id                                               name    host_id  \
# 1250  32134137  Luxury Condominium in the Center of Downtown A...  167186184
# 1272  32515511  Luxury Condominium in the Center of Downtown A...  167186184
# 1306  33160539  Luxury Condominium in the Center of Downtown A...  167186184
# 1420  35218486  Luxury Condominium in the Center of Downtown A...  167186184
#
#      host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 1250     Towns                  NaN          28801  35.59164  -82.55783
# 1272     Towns                  NaN          28801  35.59182  -82.55628
# 1306     Towns                  NaN          28801  35.59226  -82.55757
# 1420     Towns                  NaN          28801  35.59210  -82.55613
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 1250  Entire home/apt    281               1                 71  2020-12-01
# ...

# %%
Airbnb_data.drop(columns='neighbourhood_group', inplace=True)

# %%
Airbnb_data.head(10)
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 2  156926             Mixed Dorm "Top Bunk #1" at BPS Hostel   746673
# 3  160594                                Historic Grove Park   769252
# 4  209068                                    Terrace Cottage  1029919
# 5  213006                                     Blue Gate West  1098412
# 6  246315                          Asheville Dreamer's Cabin  1292070
# 7  259576           Private, peaceful, and free goat therapy  1362726
# 8  295496                  The Fern Street Apt near Biltmore  1501882
# 9  304379                         Refocus Cottage - paradise  1566145
#
#    host_name  neighbourhood  latitude  longitude        room_type  price  \
# 0       Lisa          28801  35.60670  -82.55563  Entire home/apt     82
# ...

# %%
from datetime import datetime,timedelta
from datetime import date, datetime
now = datetime.now()
#Airbnb_data['Day_ount'] = now.year - Airbnb_data['last_review']
Airbnb_data['diff'] =  (datetime.now()-pd.to_datetime(Airbnb_data['last_review'],format ="%Y-%m-%d")).dt.days

#Airbnb_data['diff'] = Airbnb_data['diff'].str.replace('days +00:57:47.329958', ' ')


#df['age']=df['age'].replace(to_replace =np.nan, value = 0)
Airbnb_data.head()
# Out:
#        id                                               name  host_id  \
# 0  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 1  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 2  156926             Mixed Dorm "Top Bunk #1" at BPS Hostel   746673
# 3  160594                                Historic Grove Park   769252
# 4  209068                                    Terrace Cottage  1029919
#
#    host_name  neighbourhood  latitude  longitude        room_type  price  \
# 0       Lisa          28801  35.60670  -82.55563  Entire home/apt     82
# 1    BonPaul          28806  35.57864  -82.59578  Entire home/apt     90
# 2    BonPaul          28806  35.57864  -82.59578      Shared room     30
# 3  Elizabeth          28801  35.61442  -82.54127     Private room    125
# 4      Kevin          28804  35.61856  -82.55276  Entire home/apt    134
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
#Code task 5#
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#ski_data as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([Airbnb_data.isnull().sum(), 100 * Airbnb_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'])
# Out:
#                                 count         %
# id                                  0  0.000000
# name                                0  0.000000
# host_id                             0  0.000000
# neighbourhood                       0  0.000000
# latitude                            0  0.000000
# longitude                           0  0.000000
# room_type                           0  0.000000
# price                               0  0.000000
# minimum_nights                      0  0.000000
# number_of_reviews                   0  0.000000
# calculated_host_listings_count      0  0.000000
# availability_365                    0  0.000000
# host_name                           1  0.044287
# last_review                       175  7.750221
# reviews_per_month                 175  7.750221
# diff                              175  7.750221

# %%
state_price_means = Airbnb_data.groupby('neighbourhood')[['price']].mean()
state_price_means.head(20)
# Out:
#                     price
# neighbourhood
# 28704          173.683824
# 28715          163.823529
# 28732          191.929825
# 28801          182.063492
# 28803          176.285714
# 28804          226.232210
# 28805          173.024390
# 28806          137.449111

# %%
(state_price_means.reindex(index=state_price_means.mean(axis=1)
    .sort_values(ascending=False)
    .index)
    .plot(kind='barh', figsize=(10, 10), title='Average  price by neighborhood'))
plt.xlabel('Price ($)');

# %%
ticket_prices = pd.melt(Airbnb_data[['neighbourhood', 'price']], 
                        id_vars=['neighbourhood'], 
                        var_name='Ticket', 
                        value_vars= ['price'],
                        value_name ='price' )
# Out:
# C:\Users\Mohammad\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resultiing Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Code task 16#
#Create a seaborn boxplot of the ticket price dataframe we created above,
#with 'state' on the x-axis, 'Price' as the y-value, and a hue that indicates 'Ticket'
#This will use boxplot's x, y, hue, and data arguments.
plt.subplots(figsize=(12, 8))
sns.boxplot(x='neighbourhood', y='price', hue='Ticket', data=ticket_prices)
plt.xticks(rotation='vertical')
plt.ylabel('Price ($)')
plt.xlabel('Area');

# %%
#Code task 18#
#Call ski_data's `hist` method to plot histograms of each of the numeric features
#Try passing it an argument figsize=(15,10)
#Try calling plt.subplots_adjust() with an argument hspace=0.5 to adjust the spacing
#It's important you create legible and easy-to-read plots
Airbnb_data.hist(figsize=(15, 10))
plt.subplots_adjust(hspace=0.5)
#plt.subplots_adjust(hspace=___);
#Hint: notice how the terminating ';' "swallows" some messy output and leads to a tidier notebook

# %%
Airbnb_data[Airbnb_data.price> 8000]
# Out:
#             id                       name    host_id          host_name  \
# 1245  32067034  Cozy Cottage on the Creek  134903005  Carolina Mornings
#
#       neighbourhood  latitude  longitude        room_type  price  \
# 1245          28804  35.64886  -82.62747  Entire home/apt  10000
#
#       minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1245               1                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365  diff
# 1245                              19               169   NaN

# %%
Airbnb_data=Airbnb_data[Airbnb_data.price< 8000]

# %%
ticket_prices = pd.melt(Airbnb_data[['neighbourhood', 'price']], 
                        id_vars=['neighbourhood'], 
                        var_name='Ticket', 
                        value_vars= ['price'],
                        value_name ='price' )
# Out:
# C:\Users\Mohammad\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resultiing Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Code task 16#
#Create a seaborn boxplot of the ticket price dataframe we created above,
#with 'state' on the x-axis, 'Price' as the y-value, and a hue that indicates 'Ticket'
#This will use boxplot's x, y, hue, and data arguments.
plt.subplots(figsize=(12, 8))
sns.boxplot(x='neighbourhood', y='price', hue='Ticket', data=ticket_prices)
plt.xticks(rotation='vertical')
plt.ylabel('Price ($)')
plt.xlabel('State');

# %%
Airbnb_data.head(20)
# Out:
#         id                                               name   host_id  \
# 0   108061  Walk to stores/parks/downtown. Fenced yard/Pet...    320564
# 1   155305                 Cottage! BonPaul + Sharky's Hostel    746673
# 2   156926             Mixed Dorm "Top Bunk #1" at BPS Hostel    746673
# 3   160594                                Historic Grove Park    769252
# 4   209068                                    Terrace Cottage   1029919
# 5   213006                                     Blue Gate West   1098412
# 6   246315                          Asheville Dreamer's Cabin   1292070
# 7   259576           Private, peaceful, and free goat therapy   1362726
# 8   295496                  The Fern Street Apt near Biltmore   1501882
# 9   304379                         Refocus Cottage - paradise   1566145
# 10  353092                Athena's Loft:  Find yourself here!   1788071
# 11  427497           Luxurious Mountain Guest Suite Apartment   1909922
# ...

# %%
Airbnb_data.to_csv('C:/Users/Mohammad/DataScienceCapstone/data1/Airbnb_data.csv')

# %%
import numpy as np
reviews_per_month_mean=Airbnb_data['reviews_per_month'].mean(axis=0) 
Airbnb_data['reviews_per_month']=Airbnb_data['reviews_per_month'].replace(to_replace =np.nan, 
                 value = reviews_per_month_mean) 

mean_diff=Airbnb_data['diff'].mean(axis=0) 
Airbnb_data['diff']=Airbnb_data['diff'].replace(to_replace =np.nan, 
                 value = mean_diff) 
#Airbnb_data=Airbnb_data.dropna()

# %%
Airbnb_data['host_name']=Airbnb_data['host_name'].replace(to_replace =np.nan, 
                 value = 'missing') 




Airbnb_data['last_review']=Airbnb_data['last_review'].replace(to_replace =np.nan, 
                 value = 'missing')

# %%
missing = pd.concat([Airbnb_data.isnull().sum(), 100 * Airbnb_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'])
# Out:
#                                 count    %
# id                                  0  0.0
# name                                0  0.0
# host_id                             0  0.0
# host_name                           0  0.0
# neighbourhood                       0  0.0
# latitude                            0  0.0
# longitude                           0  0.0
# room_type                           0  0.0
# price                               0  0.0
# minimum_nights                      0  0.0
# number_of_reviews                   0  0.0
# last_review                         0  0.0
# reviews_per_month                   0  0.0
# calculated_host_listings_count      0  0.0
# availability_365                    0  0.0
# diff                                0  0.0

# %%
df = Airbnb_data.drop(['host_name','latitude','last_review','host_id','name','longitude'],axis =1)

# %%
df.head()
# Out:
#        id  neighbourhood        room_type  price  minimum_nights  \
# 0  108061          28801  Entire home/apt     82              30
# 1  155305          28806  Entire home/apt     90               1
# 2  156926          28806      Shared room     30               1
# 3  160594          28801     Private room    125              30
# 4  209068          28804  Entire home/apt    134              30
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                 89               0.79                               2
# 1                279               2.44                               6
# 2                290               2.78                               6
# 3                 58               0.51                               1
# 4                 56               0.50                               1
#
#    availability_365    diff
# 0               173   516.0
# 1               352   144.0
# 2                 0   179.0
# ...

# %%
df.room_type.unique()
# Out:
# array(['Entire home/apt', 'Shared room', 'Private room', 'Hotel room'],
#       dtype=object)

# %%
#define the response variable
y=df['price']

#Dummy feature creation
def dumdum(df, features_to_exclude):
    dfo = df.select_dtypes(include=['object'])
    du = pd.get_dummies(df.drop(features_to_exclude,axis =1))
    dfn = df.select_dtypes(exclude=['object'])
    df = dfn.merge(du,left_index=True,right_index=True)
    return df  

df1 = dumdum(df.drop('id', axis=1),['price'])

# %%
from sklearn.model_selection import train_test_split
X=df1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 200, random_state = 20)
  
# fit the regressor with x and y data
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=20)

# %%
y_tr_regressor_pred = regressor.predict(X_train)
y_tr_regressor_pred[:5]
# Out:
# array([ 98.   , 163.925, 157.985, 218.985,  76.   ])

# %%
df1.head()
# Out:
#    neighbourhood_x  price  minimum_nights_x  number_of_reviews_x  \
# 0            28801     82                30                   89
# 1            28806     90                 1                  279
# 2            28806     30                 1                  290
# 3            28801    125                30                   58
# 4            28804    134                30                   56
#
#    reviews_per_month_x  calculated_host_listings_count_x  availability_365_x  \
# 0                 0.79                                 2                 173
# 1                 2.44                                 6                 352
# 2                 2.78                                 6                   0
# 3                 0.51                                 1                   0
# 4                 0.50                                 1                 345
#
#    diff_x  neighbourhood_y  minimum_nights_y  number_of_reviews_y  \
# ...

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %%
class_names=['Entire home/apt', 'Shared room', 'Private room', 'Hotel room'] # name  of classes

# %%
df1.head()
# Out:
#    neighbourhood_x  price_x  minimum_nights  number_of_reviews_x  \
# 0            28801       82              30                   89
# 1            28806       90               1                  279
# 2            28806       30               1                  290
# 3            28801      125              30                   58
# 4            28804      134              30                   56
#
#    reviews_per_month_x  calculated_host_listings_count_x  availability_365_x  \
# 0                 0.79                                 2                 173
# 1                 2.44                                 6                 352
# 2                 2.78                                 6                   0
# 3                 0.51                                 1                   0
# 4                 0.50                                 1                 345
#
#    diff_x  neighbourhood_y  price_y  number_of_reviews_y  reviews_per_month_y  \
# ...

# %%
df1.head()
# Out:
#    neighbourhood_x  price  minimum_nights_x  number_of_reviews_x  \
# 0            28801     82                30                   89
# 1            28806     90                 1                  279
# 2            28806     30                 1                  290
# 3            28801    125                30                   58
# 4            28804    134                30                   56
#
#    reviews_per_month_x  calculated_host_listings_count_x  availability_365_x  \
# 0                 0.79                                 2                 173
# 1                 2.44                                 6                 352
# 2                 2.78                                 6                   0
# 3                 0.51                                 1                   0
# 4                 0.50                                 1                 345
#
#    diff_x  neighbourhood_y  minimum_nights_y  number_of_reviews_y  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df1.drop(columns='price'), 
                                                    df1.price, test_size=0.2, 
                                                    random_state=5)

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
import datetime

# %%
dumb_reg = DummyRegressor(strategy='mean')
dumb_reg.fit(X_train, y_train)
dumb_reg.constant_
# Out:
# array([[170.86655592]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression


# Split the data into a training and test set.


clf = LogisticRegression()
# Fit the model on the trainng data.
clf.fit(X_train, y_train)
# Print the accuracy from the testing data.
# Out:
# C:\Users\Mohammad\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 200, random_state = 20)
  
# fit the regressor with x and y data
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=20)

# %%
def r_squared(y, ypred):
    """R-squared score.
    
    Calculate the R-squared, or coefficient of determination, of the input.
    
    Arguments:
    y -- the observed values
    ypred -- the predicted values
    """
    ybar = np.sum(y) / len(y) #yes, we could use np.mean(y)
    sum_sq_tot = np.sum((y - ybar)**2) #total sum of squares error
    sum_sq_res = np.sum((y - ypred)**2) #residual sum of squares error
    R2 = 1.0 - sum_sq_res / sum_sq_tot
    return R2

# %%
y_tr_regressor_pred = regressor.predict(X_train)
y_tr_regressor_pred[:5]
# Out:
# array([106.95,  77.  , 329.21, 246.12,  73.05])

# %%
r_squared(y_train, y_tr_regressor_pred)
# Out:
# -0.286901805059661

# %%
#Code task 7#
#Calculate the MAE as defined above
def mae(y, ypred):
    """Mean absolute error.
    
    Calculate the mean absolute error of the arguments

    Arguments:
    y -- the observed values
    ypred -- the predicted values
    """
    abs_error = np.abs(y-ypred)
    mae = np.mean(abs_error)
    return mae

# %%
mae(y_train, y_tr_regressor_pred)
# Out:
# 133.21568660022137

# %%
#Code task 8#
#Calculate the MSE as defined above
def mse(y, ypred):
    """Mean square error.
    
    Calculate the mean square error of the arguments

    Arguments:
    y -- the observed values
    ypred -- the predicted values
    """
    sq_error = (y- ypred)**2
    mse = np.mean(sq_error)
    return mse

# %%
mse(y_train, y_tr_regressor_pred)
# Out:
# 98167.01369969545

# %%
Airbnb_cleaned3=df1

# %%
Airbnb_cleaned3.head()
# Out:
#    neighbourhood_x  price_x  minimum_nights  number_of_reviews_x  \
# 0            28801       82              30                   89
# 1            28806       90               1                  279
# 2            28806       30               1                  290
# 3            28801      125              30                   58
# 4            28804      134              30                   56
#
#    reviews_per_month_x  calculated_host_listings_count_x  availability_365_x  \
# 0                 0.79                                 2                 173
# 1                 2.44                                 6                 352
# 2                 2.78                                 6                   0
# 3                 0.51                                 1                   0
# 4                 0.50                                 1                 345
#
#    diff_x  neighbourhood_y  price_y  number_of_reviews_y  reviews_per_month_y  \
# ...

# %%
datapath = 'C:/Users/Mohammad/DataScienceCapstone/data1'
# renaming the output data directory and re-running this notebook, for example,
# will recreate this (empty) directory and resave the data files.
# NB this is not a substitute for a modern data pipeline, for which there are
# various tools. However, for our purposes here, and often in a "one off" analysis,
# this is useful because we have to deliberately move/delete our data in order
# to overwrite it.
if not os.path.exists(datapath):
    os.mkdir(datapath)

# %%
Airbnb_cleaned3.to_csv('C:/Users/Mohammad/DataScienceCapstone/data1/Airbnb_cleaned3.csv')

# %%
Airbnb_data.to_csv('C:/Users/Mohammad/DataScienceCapstone/data1/Airbnb_data.csv')

# %%
datapath_Airbnbdata = os.path.join(datapath, 'Airbnb_cleaned3.csv')
if not os.path.exists(datapath_Airbnbdata):
    Airbnb_data.to_csv(datapath_Airbnbdata, index=False)

# %%
datapath_Airbnbdata = os.path.join(datapath, 'Airbnb_data.csv')
if not os.path.exists(datapath_Airbnbdata):
    Airbnb_data.to_csv(datapath_Airbnbdata, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4b5ee831244f> in <module>
# ----> 1 datapath_Airbnbdata = os.path.join(datapath, 'Airbnb_data.csv')
#       2 if not os.path.exists(datapath_Airbnbdata):
#       3     Airbnb_data.to_csv(datapath_Airbnbdata, index=False)
#
# NameError: name 'datapath' is not defined
